# %%
#1
s = input()
words = s.split()
print(len(words))
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА
# 4

# %%
#2
s = input().split()
count = 0
for word in s:
    if word[0] == word[-1]:
        count += 1
print(count)
# Out:
#  АЛГЕБРА ПРИВЕТ МАМА ПАПА ТЕСТ
# 2

# %%
#3
s = input().split()
count = 0
for word in s:
    if 'А' in word:
        count += 1
print(count)
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА АННА
# 3

# %%
#4
s = input().split()
min_len = min(len(word) for word in s)
print(min_len)
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА Я
# 1

# %%
#5
s = input().split()
print(' '.join(s[::-1]))
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА
# ДЕЛА КАК МИР ПРИВЕТ

# %%
#6
s = input().split()
print(' '.join(sorted(s)))
# Out:
#  БАНАН ЯБЛОКО АПЕЛЬСИН ВИШНЯ
# АПЕЛЬСИН БАНАН ВИШНЯ ЯБЛОКО

# %%
#7
C = input()
S = input()
S0 = input()
result = S0.join(S.split(C))
print(result)
# Out:
#  А
#  БАНАН
#  Я
# БЯНЯН

# %%
#8
s = input()
print(' '.join(s.split()))
# Out:
#  ПРИВЕТ    МИР    КАК     ДЕЛА
# ПРИВЕТ МИР КАК ДЕЛА

# %%
#9
s = input()
count = 0
for char in s:
    if char.isalpha() and char.islower():
        count += 1
print(count)
# Out:
#  Hello мир привет test
# 17

# %%
#10
s = input().split()
max_len = max(len(word) for word in s)
print(max_len)
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА ПРОГРАММИРОВАНИЕ
# 16

# %%
#11
s = input()
even = s[1::2]
odd = s[0::2][::-1]
print(even + odd)
# Out:
#  Программа
# ргамамроП

# %%
#12
S = input()
N = int(input())
result = ('*' * N).join(S)
print(result)
# Out:
#  ABC
#  2
# A**B**C

# %%
#13
s = input().split()
print('.'.join(s))
# Out:
#  ПРИВЕТ МИР КАК ДЕЛА
# ПРИВЕТ.МИР.КАК.ДЕЛА

# %%
#14
path = input()
filename = path.split('\\')[-1]
name = filename.split('.')[0]
print(name)
# Out:
#  d:\ivanov\primer\prog.py
# prog

# %%
#15
s = input().split()
longest = max(s, key=len)
print(longest)
# Out:
#  ПРИВЕТ МИР ПРОГРАММИРОВАНИЕ КОД
# ПРОГРАММИРОВАНИЕ
